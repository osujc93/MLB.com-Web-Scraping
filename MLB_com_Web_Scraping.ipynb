# %%
import pandas as pd
import requests
pd.set_option('display.max_columns', None)
import time
import numpy as np

# %% [markdown]
# ****
#
# # **Team Stats**
#
# ****

# %% [markdown]
# ****
#
# ## **Team Hitting Stats (2023)**
#
# ****

# %%
test_url = 'https://bdfed.stitch.mlbinfra.com/bdfed/stats/team?stitch_env=prod&sportId=1&gameType=R&group=hitting&order=desc&sortStat=homeRuns&stats=season&season=2023&limit=30&offset=0'

# %%
r = requests.get(url=test_url).json()

# %%
r['stats']
# Out:
# [{'year': '2024',
#   'type': 'team',
#   'rank': 1,
#   'shortName': 'Baltimore',
#   'teamId': 110,
#   'teamAbbrev': 'BAL',
#   'teamName': 'Baltimore Orioles',
#   'teamShortName': 'Orioles',
#   'leagueAbbrev': 'AL',
#   'leagueName': 'American League',
#   'leagueShortName': 'American',
#   'gamesPlayed': 33,
#   'groundOuts': 255,
#   'airOuts': 333,
#   'runs': 169,
#   'doubles': 54,
#   'triples': 7,
#   'homeRuns': 51,
#   'strikeOuts': 277,
#   'baseOnBalls': 84,
#   'intentionalWalks': 1,
#   'hits': 283,
#   'hitByPitch': 17,
#   'avg': '.249',
#   'atBats': 1137,
#   'obp': '.308',
#   'slg': '.443',
#   'ops': '.751',
#   'caughtStealing': 3,
#   'stolenBases': 26,
#   'stolenBasePercentage': '.897',
#   'groundIntoDoublePlay': 9,
#   'numberOfPitches': 4773,
#   'plateAppearances': 1250,
#   'totalBases': 504,
#   'rbi': 163,
#   'leftOnBase': 214,
#   'sacBunts': 1,
#   'sacFlies': 10,
#   'babip': '.283',
#   'groundOutsToAirouts': '0.77',
# ...

# %%
pd.DataFrame(r['stats'])
# Out:
#     year  type  rank      shortName  teamId teamAbbrev               teamName  \
# 0   2024  team     1      Baltimore     110        BAL      Baltimore Orioles
# 1   2024  team     2     LA Dodgers     119        LAD    Los Angeles Dodgers
# 2   2024  team     2        Oakland     133        OAK      Oakland Athletics
# 3   2024  team     4     NY Yankees     147        NYY       New York Yankees
# 4   2024  team     5   Philadelphia     143        PHI  Philadelphia Phillies
# 5   2024  team     6      Milwaukee     158        MIL      Milwaukee Brewers
# 6   2024  team     6      San Diego     135         SD       San Diego Padres
# 7   2024  team     8        Houston     117        HOU         Houston Astros
# 8   2024  team     9         Boston     111        BOS         Boston Red Sox
# 9   2024  team     9      LA Angels     108        LAA     Los Angeles Angels
# 10  2024  team    11       Chi Cubs     112        CHC           Chicago Cubs
# ...

# %%
mlb_team_hitting_stats = pd.DataFrame(r['stats'])

# %%
mlb_team_hitting_stats
# Out:
#     year  type  rank      shortName  teamId teamAbbrev               teamName  \
# 0   2024  team     1      Baltimore     110        BAL      Baltimore Orioles
# 1   2024  team     2     LA Dodgers     119        LAD    Los Angeles Dodgers
# 2   2024  team     2        Oakland     133        OAK      Oakland Athletics
# 3   2024  team     4     NY Yankees     147        NYY       New York Yankees
# 4   2024  team     5   Philadelphia     143        PHI  Philadelphia Phillies
# 5   2024  team     6      Milwaukee     158        MIL      Milwaukee Brewers
# 6   2024  team     6      San Diego     135         SD       San Diego Padres
# 7   2024  team     8        Houston     117        HOU         Houston Astros
# 8   2024  team     9         Boston     111        BOS         Boston Red Sox
# 9   2024  team     9      LA Angels     108        LAA     Los Angeles Angels
# 10  2024  team    11       Chi Cubs     112        CHC           Chicago Cubs
# ...

# %%
mlb_team_hitting_stats.columns
# Out:
# Index(['year', 'type', 'rank', 'shortName', 'teamId', 'teamAbbrev', 'teamName',
#        'teamShortName', 'leagueAbbrev', 'leagueName', 'leagueShortName',
#        'gamesPlayed', 'groundOuts', 'airOuts', 'runs', 'doubles', 'triples',
#        'homeRuns', 'strikeOuts', 'baseOnBalls', 'intentionalWalks', 'hits',
#        'hitByPitch', 'avg', 'atBats', 'obp', 'slg', 'ops', 'caughtStealing',
#        'stolenBases', 'stolenBasePercentage', 'groundIntoDoublePlay',
#        'numberOfPitches', 'plateAppearances', 'totalBases', 'rbi',
#        'leftOnBase', 'sacBunts', 'sacFlies', 'babip', 'groundOutsToAirouts',
#        'catchersInterference', 'atBatsPerHomeRun'],
#       dtype='object')

# %% [markdown]
# ****
#
# ## **Team Pitching Stats (2023)**
#
# ****

# %%
test_url2 = 'https://bdfed.stitch.mlbinfra.com/bdfed/stats/team?stitch_env=prod&sportId=1&gameType=R&group=pitching&order=asc&sortStat=earnedRunAverage&stats=season&season=2023&limit=30&offset=0'

# %%
r2 = requests.get(url=test_url2).json()

# %%
r2['stats']
# Out:
# [{'year': '2023',
#   'type': 'team',
#   'rank': 1,
#   'shortName': 'Milwaukee',
#   'teamId': 158,
#   'teamAbbrev': 'MIL',
#   'teamName': 'Milwaukee Brewers',
#   'teamShortName': 'Brewers',
#   'leagueAbbrev': 'NL',
#   'leagueName': 'National League',
#   'leagueShortName': 'National',
#   'gamesPlayed': 162,
#   'gamesStarted': 162,
#   'groundOuts': 1368,
#   'airOuts': 1420,
#   'runs': 647,
#   'doubles': 225,
#   'triples': 16,
#   'homeRuns': 198,
#   'strikeOuts': 1425,
#   'baseOnBalls': 493,
#   'intentionalWalks': 7,
#   'hits': 1218,
#   'hitByPitch': 60,
#   'avg': '.226',
#   'atBats': 5380,
#   'obp': '.297',
#   'slg': '.385',
#   'ops': '.682',
#   'caughtStealing': 23,
#   'stolenBases': 121,
#   'stolenBasePercentage': '.840',
#   'groundIntoDoublePlay': 100,
#   'numberOfPitches': 23543,
#   'era': '3.71',
#   'inningsPitched': '1443.0',
#   'wins': 92,
#   'losses': 70,
#   'saves': 46,
#   'saveOpportunities': 71,
#   'holds': 103,
#   'blownSaves': 25,
# ...

# %%
pd.DataFrame(r2['stats'])
# Out:
#     year  type  rank      shortName  teamId teamAbbrev               teamName  \
# 0   2023  team     1      Milwaukee     158        MIL      Milwaukee Brewers
# 1   2023  team     2      San Diego     135         SD       San Diego Padres
# 2   2023  team     3        Seattle     136        SEA       Seattle Mariners
# 3   2023  team     4        Toronto     141        TOR      Toronto Blue Jays
# 4   2023  team     5      Tampa Bay     139         TB         Tampa Bay Rays
# 5   2023  team     6      Minnesota     142        MIN        Minnesota Twins
# 6   2023  team     7      Baltimore     110        BAL      Baltimore Orioles
# 7   2023  team     8        Houston     117        HOU         Houston Astros
# 8   2023  team     9      Cleveland     114        CLE    Cleveland Guardians
# 9   2023  team    10     NY Yankees     147        NYY       New York Yankees
# 10  2023  team    11  San Francisco     137         SF   San Francisco Giants
# ...

# %%
mlb_team_pitching_stats = pd.DataFrame(r2['stats'])

# %%
mlb_team_pitching_stats
# Out:
#     year  type  rank      shortName  teamId teamAbbrev               teamName  \
# 0   2023  team     1      Milwaukee     158        MIL      Milwaukee Brewers
# 1   2023  team     2      San Diego     135         SD       San Diego Padres
# 2   2023  team     3        Seattle     136        SEA       Seattle Mariners
# 3   2023  team     4        Toronto     141        TOR      Toronto Blue Jays
# 4   2023  team     5      Tampa Bay     139         TB         Tampa Bay Rays
# 5   2023  team     6      Minnesota     142        MIN        Minnesota Twins
# 6   2023  team     7      Baltimore     110        BAL      Baltimore Orioles
# 7   2023  team     8        Houston     117        HOU         Houston Astros
# 8   2023  team     9      Cleveland     114        CLE    Cleveland Guardians
# 9   2023  team    10     NY Yankees     147        NYY       New York Yankees
# 10  2023  team    11  San Francisco     137         SF   San Francisco Giants
# ...

# %%
mlb_team_pitching_stats.columns
# Out:
# Index(['year', 'type', 'rank', 'shortName', 'teamId', 'teamAbbrev', 'teamName',
#        'teamShortName', 'leagueAbbrev', 'leagueName', 'leagueShortName',
#        'gamesPlayed', 'gamesStarted', 'groundOuts', 'airOuts', 'runs',
#        'doubles', 'triples', 'homeRuns', 'strikeOuts', 'baseOnBalls',
#        'intentionalWalks', 'hits', 'hitByPitch', 'avg', 'atBats', 'obp', 'slg',
#        'ops', 'caughtStealing', 'stolenBases', 'stolenBasePercentage',
#        'groundIntoDoublePlay', 'numberOfPitches', 'era', 'inningsPitched',
#        'wins', 'losses', 'saves', 'saveOpportunities', 'holds', 'blownSaves',
#        'earnedRuns', 'whip', 'battersFaced', 'outs', 'gamesPitched',
#        'completeGames', 'shutouts', 'strikes', 'strikePercentage',
#        'hitBatsmen', 'balks', 'wildPitches', 'pickoffs', 'totalBases',
#        'groundOutsToAirouts', 'winPercentage', 'pitchesPerInning',
#        'gamesFinished', 'strikeoutWalkRatio', 'strikeoutsPer9Inn',
# ...

# %% [markdown]
# ****
#
# ## **Team Hitting & Pitching Stats (1990-2024)**
#
# ****

# %%
df_cols = mlb_team_hitting_stats.columns

# %%
headers = {
    'Accept': '*/*',
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Accept-Language': 'en-US,en;q=0.9',
    'Cache-Control': 'no-cache',
    'Origin': 'https://www.mlb.com',
    'Pragma': 'no-cache',
    'Priority': 'u=1, i',
    'Referer': 'https://www.mlb.com/',
    'Sec-Ch-Ua': '"Chromium";v="124", "Google Chrome";v="124", "Not-A.Brand";v="99"',
    'Sec-Ch-Ua-Mobile': '?0',
    'Sec-Ch-Ua-Platform': "Windows",
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'cross-site',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36'
}

# %%
hitting_stats = pd.DataFrame(columns=df_cols)
hitting_stats

begin_loop = time.time()

years = range(1990, 2025)
group = ['hitting', 'pitching']

for y in years:
    for g in group:
        api_url = f'https://bdfed.stitch.mlbinfra.com/bdfed/stats/team?stitch_env=prod&sportId=1&gameType=R&group={g}&order=desc&sortStat=homeRuns&stats=season&season={y}&limit=30&offset=0'
        r = requests.get(url=api_url, headers=headers).json()
        h_stats_df1 = pd.DataFrame(r['stats'])
        h_stats_df2 = pd.DataFrame({'Year':[y for i in range(len(h_stats_df1))],
                                    'group':[g for i in range(len(h_stats_df1))]})
        h_stats_df3 = pd.concat([h_stats_df2, h_stats_df1], axis=1)

        hitting_stats = pd.concat([hitting_stats, h_stats_df3], ignore_index=True)

        print(f'Finished scraping data for {y} season.')
        lag = np.random.uniform(1, 3)
        print (f'...waiting {round(lag,1)} seconds')
        time.sleep(lag)

hitting_stats = hitting_stats.sort_values(by=['Year', 'group', 'homeRuns', 'era'], ascending=[False, True, False, True])

print(f'Process completed in {time.time() - begin_loop} seconds')
# Out:
# Finished scraping data for 1990 season.
# ...waiting 2.4 seconds
# Finished scraping data for 1990 season.
# ...waiting 1.3 seconds
# Finished scraping data for 1991 season.
# ...waiting 1.6 seconds
# Finished scraping data for 1991 season.
# ...waiting 1.4 seconds
# Finished scraping data for 1992 season.
# ...waiting 1.8 seconds
# Finished scraping data for 1992 season.
# ...waiting 1.2 seconds
# Finished scraping data for 1993 season.
# ...waiting 1.5 seconds
# Finished scraping data for 1993 season.
# ...waiting 1.2 seconds
# Finished scraping data for 1994 season.
# ...waiting 2.7 seconds
# Finished scraping data for 1994 season.
# ...waiting 1.3 seconds
# Finished scraping data for 1995 season.
# ...waiting 2.1 seconds
# Finished scraping data for 1995 season.
# ...waiting 2.4 seconds
# Finished scraping data for 1996 season.
# ...waiting 1.5 seconds
# Finished scraping data for 1996 season.
# ...waiting 2.8 seconds
# Finished scraping data for 1997 season.
# ...

# %%
hitting_stats.fillna(0, inplace=True)

# %%
hitting_stats
# Out:
#       year  type rank      shortName teamId teamAbbrev               teamName  \
# 1996  2024  team    1      Baltimore    110        BAL      Baltimore Orioles
# 1997  2024  team    2     LA Dodgers    119        LAD    Los Angeles Dodgers
# 1998  2024  team    2        Oakland    133        OAK      Oakland Athletics
# 1999  2024  team    4     NY Yankees    147        NYY       New York Yankees
# 2000  2024  team    5   Philadelphia    143        PHI  Philadelphia Phillies
# ...    ...   ...  ...            ...    ...        ...                    ...
# 47    1990  team   22          Texas    140        TEX          Texas Rangers
# 49    1990  team   23  Chi White Sox    145        CWS      Chicago White Sox
# 48    1990  team   23     California    108        CAL      California Angels
# 50    1990  team   25      St. Louis    138        STL    St. Louis Cardinals
# 51    1990  team   26         Boston    111        BOS         Boston Red Sox
#
# ...

# %%
hitting_stats.columns
# Out:
# Index(['year', 'type', 'rank', 'shortName', 'teamId', 'teamAbbrev', 'teamName',
#        'teamShortName', 'leagueAbbrev', 'leagueName', 'leagueShortName',
#        'gamesPlayed', 'groundOuts', 'airOuts', 'runs', 'doubles', 'triples',
#        'homeRuns', 'strikeOuts', 'baseOnBalls', 'intentionalWalks', 'hits',
#        'hitByPitch', 'avg', 'atBats', 'obp', 'slg', 'ops', 'caughtStealing',
#        'stolenBases', 'stolenBasePercentage', 'groundIntoDoublePlay',
#        'numberOfPitches', 'plateAppearances', 'totalBases', 'rbi',
#        'leftOnBase', 'sacBunts', 'sacFlies', 'babip', 'groundOutsToAirouts',
#        'catchersInterference', 'atBatsPerHomeRun', 'Year', 'group',
#        'gamesStarted', 'era', 'inningsPitched', 'wins', 'losses', 'saves',
#        'saveOpportunities', 'holds', 'blownSaves', 'earnedRuns', 'whip',
#        'battersFaced', 'outs', 'gamesPitched', 'completeGames', 'shutouts',
#        'strikes', 'strikePercentage', 'hitBatsmen', 'balks', 'wildPitches',
# ...

# %% [markdown]
# ****
#
#
# # **Random Forest Regressor**
#
# ### **Utilized for feature importance analysis**
#
#
# **It constructs multiple decision trees during training and outputs the average prediction of the individual trees.**
#
# **It is a form of ensemble learning technique that combines multiple models to improve the overall model performance, especially in terms of variance reduction.**
#
#
# **Bootstrap Aggregating (Bagging):**
# Random Forest creates multiple decision trees, each trained on a bootstrap sample of the data.
# $$ \text{For } i = 1 \text{ to } N: $$
# $$ D_i = \text{BootstrapSample}(\text{TrainingData}) $$
# $$ T_i = \text{TrainDecisionTree}(D_i) $$
# - \( N \): Total number of trees in the forest
# - \( D_i \): Bootstrap sample for the \( i \)-th tree
# - \( T_i \): Decision tree trained on \( D_i \)
#
# **Random Feature Selection:**
# In each decision tree, a subset of features is randomly selected at each split.
# $$ \text{FeatureSubset} = \text{RandomSelect}(\text{Features}, K) $$
# - \(Features\): Set of all features
# - \( K \): Number of features to select at each split
#
# **Model Prediction:**
# The Random Forest prediction is the average of predictions from all the trees.
# $$ \text{RF Prediction} = \frac{1}{N} \sum_{i=1}^{N} T_i(\text{input}) $$
# - \(RF Prediction\): Output prediction of the Random Forest model
# - \( T_i(input}) \): Prediction made by the \( i \)-th tree
#
# **Feature Importance Estimation:**
# Random Forest evaluates the importance of each feature based on its contribution to reducing impurity.
# $$ \text{Importance}(F) = \text{AvgDecreaseImpurity}(F, \{T_i\}) $$
# - \( F \): A specific feature
# - \( \{T_i\} \): Set of all trees in the forest
#
# **Out-Of-Bag (OOB) Error Estimation:**
# OOB error is an estimate of prediction error for bagged decision trees.
# $$ \text{OOB Error} = \text{AvgError}(\{T_i(\text{OOB}_i)\}) $$
# - \(OOB_i\): Out-of-bag samples for the \( i \)-th tree
# - \( T_i(OOB_i) \): Prediction error on \( \text{OOB}_i \)
#
#
#
#
# ****

# %%
from sklearn.preprocessing import LabelEncoder

categorical_cols = hitting_stats.select_dtypes(include=['object', 'category']).columns
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    hitting_stats[col] = le.fit_transform(hitting_stats[col].astype(str))
    label_encoders[col] = le

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import pandas as pd
import matplotlib.pyplot as plt

X = hitting_stats.drop(['homeRuns', 'era'], axis=1)
y_homeRuns = hitting_stats['homeRuns']

X_train, X_test, y_train_homeRuns, y_test_homeRuns = train_test_split(X, y_homeRuns, test_size=0.2, random_state=42)

model_homeRuns = RandomForestRegressor(n_estimators=100, random_state=42)
model_homeRuns.fit(X_train, y_train_homeRuns)

importances_homeRuns = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': model_homeRuns.feature_importances_
}).sort_values(by='Importance', ascending=True)

print("Feature Importances for Home Runs:")
print(importances_homeRuns)

plt.figure(figsize=(12, 22))
plt.barh(importances_homeRuns['Feature'], importances_homeRuns['Importance'])
plt.title('Feature Importances for Home Runs')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.grid(True, linestyle='--')
plt.show()

cumulative_importances = importances_homeRuns['Importance'].cumsum()
plt.plot(range(1, len(cumulative_importances) + 1), cumulative_importances)
plt.xlabel('Number of Features')
plt.ylabel('Cumulative Importance')
plt.title('Cumulative Feature Importance')
plt.grid(True, linestyle='--')
plt.show()

threshold_rf = 0.001
N_rf = np.where(cumulative_importances > threshold_rf)[0][0] + 1
selected_features = importances_homeRuns.head(N_rf).index.tolist()

print(selected_features)
# Out:
# Feature Importances for Home Runs:
#              Feature  Importance
# 1               type    0.000000
# 10   leagueShortName    0.000036
# 51        blownSaves    0.000094
# 43             group    0.000127
# 9         leagueName    0.000141
# ..               ...         ...
# 73      homeRunsPer9    0.029577
# 25               slg    0.051100
# 14              runs    0.071394
# 41  atBatsPerHomeRun    0.177059
# 33        totalBases    0.446116
#
# [74 rows x 2 columns]
# [1, 10, 51, 43, 9, 44, 8, 60]

# %%
X = hitting_stats.drop(['homeRuns', 'era'], axis=1)
y_era = hitting_stats['era']

X_train, X_test, y_train_era, y_test_era = train_test_split(X, y_era, test_size=0.2, random_state=42)

model_era = RandomForestRegressor(n_estimators=100, random_state=42)
model_era.fit(X_train, y_train_era)

importances_era = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': model_era.feature_importances_
}).sort_values(by='Importance', ascending=True)

print("Feature Importances for ERA:")
print(importances_era)

plt.figure(figsize=(12, 22))
plt.barh(importances_era['Feature'], importances_era['Importance'])
plt.title('Feature Importances for ERA')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.grid(True, linestyle='--')
plt.show()

cumulative_importances = importances_era['Importance'].cumsum()
plt.plot(range(1, len(cumulative_importances) + 1), cumulative_importances)
plt.xlabel('Number of Features')
plt.ylabel('Cumulative Importance')
plt.title('Cumulative Feature Importance')
plt.grid(True, linestyle='--')
plt.show()

threshold_rf = 0.001
N_rf = np.where(cumulative_importances > threshold_rf)[0][0] + 1
selected_features = importances_era['Feature'].head(N_rf).index.tolist()

print(selected_features)
# Out:
# Feature Importances for ERA:
#              Feature    Importance
# 1               type  0.000000e+00
# 34               rbi  3.519803e-08
# 43             group  9.090903e-08
# 32  plateAppearances  1.504443e-07
# 38             babip  2.029523e-07
# ..               ...           ...
# 45    inningsPitched  1.822256e-04
# 55              outs  1.871591e-04
# 26               ops  3.170520e-04
# 52        earnedRuns  1.062063e-02
# 72    runsScoredPer9  9.859430e-01
#
# [74 rows x 2 columns]
# [1, 34, 43, 32, 38, 41, 10, 8, 9, 56, 35, 44, 40, 42, 0, 6, 51, 3, 5, 47, 61, 59, 50, 11, 58, 22, 2, 14, 49, 69, 27, 60, 64, 68, 4, 28, 46, 63, 21, 7, 24, 18, 37, 16, 57, 15]

# %% [markdown]
# ****
#
#
#
# # **Lasso Regression**
#
#
# Lasso Regression is a type of linear regression that uses shrinkage. Shrinkage is where data values are shrunk towards a central point, like the mean. The lasso procedure encourages simple, sparse models (models with fewer parameters). This particular type of regression is well-suited for models showing high levels of multicollinearity or when you want to automate certain parts of model selection, like variable selection/parameter elimination. Also, Lasso regression is particularly suitable for datasets where the relationship between the independent variables and the dependent variable is linear.
#
#
# $$
# \min_{\beta} \left\{ \frac{1}{2n} \sum_{i=1}^{n} (y_i - \beta_0 - \sum_{j=1}^{p} \beta_j x_{ij})^2 + \lambda \sum_{j=1}^{p} |\beta_j| \right\}
# $$
#
# where:
# - $y_i$ is the observed response for the $i$th observation.
# - $\beta_0$ is the intercept term.
# - $\beta_j$ is the coefficient of the $j$th predictor.
# - $x_{ij}$ is the value of the $j$th predictor for the $i$th observation.
# - $n$ is the total number of observations.
# - $p$ is the total number of predictors.
# - $\lambda$ is the tuning parameter that controls the strength of the penalty term, which in turn controls the amount of shrinkage applied to the coefficients.
#
# As $\lambda$ increases, more coefficients are set to zero, which results in a simpler and sparser model. The Lasso penalty term causes some coefficients to shrink towards zero and others to be exactly zero. This property can be used for variable selection or feature selection within a model.
#
#
#
# ****

# %%
from sklearn.linear_model import LassoCV, Lasso
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

categorical_cols = hitting_stats.select_dtypes(include=['object']).columns
hitting_stats[categorical_cols] = hitting_stats[categorical_cols].apply(lambda col: pd.factorize(col)[0])

X = hitting_stats.drop(['homeRuns', 'era'], axis=1)
y_home = hitting_stats['homeRuns']

X_train, X_test, y_train_home, y_test_home = train_test_split(X, y_home, test_size=0.2, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

lasso_cv = LassoCV(alphas=np.logspace(-6, 1, 100), cv=5, random_state=42)
lasso_cv.fit(X_train_scaled, y_train_home)
optimal_alpha = lasso_cv.alpha_
print(f"Optimal alpha: {optimal_alpha}")

lasso = Lasso(alpha=optimal_alpha)
lasso.fit(X_train_scaled, y_train_home)

lasso_coef = pd.DataFrame({'Feature': X_train.columns, 'Coefficient': lasso.coef_})
lasso_coef = lasso_coef[lasso_coef['Coefficient'] != 0]
lasso_coef = lasso_coef.sort_values(by='Coefficient', ascending=False)

print("Lasso Coefficients:")
print(lasso_coef)

lasso_coef.plot(kind='barh', x='Feature', y='Coefficient', title='Feature Coefficients in Lasso Model', figsize=(10, 12))
plt.xlabel('Coefficient Value')
plt.ylabel('Features')
plt.grid(True, linestyle='--')
plt.show()

threshold = 0.0001
selected_features = lasso_coef[lasso_coef['Coefficient'].abs() > threshold]['Feature'].tolist()
print("Selected features based on threshold:")
print(selected_features)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 371.99926343746483, tolerance: 298.79965825095064
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 408.82800310396124, tolerance: 298.79965825095064
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 401.530862494139, tolerance: 298.79965825095064
#   model = cd_fast.enet_coordinate_descent_gram(
# ...

# %%
categorical_cols = hitting_stats.select_dtypes(include=['object']).columns
hitting_stats[categorical_cols] = hitting_stats[categorical_cols].apply(lambda col: pd.factorize(col)[0])

X = hitting_stats.drop(['homeRuns', 'era'], axis=1)
y_era = hitting_stats['era']

X_train, X_test, y_train_era, y_test_era = train_test_split(X, y_era, test_size=0.2, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

lasso_cv = LassoCV(alphas=np.logspace(-6, 1, 100), cv=5, random_state=42)
lasso_cv.fit(X_train_scaled, y_train_era)
optimal_alpha = lasso_cv.alpha_
print(f"Optimal alpha: {optimal_alpha}")

lasso = Lasso(alpha=optimal_alpha)
lasso.fit(X_train_scaled, y_train_era)

lasso_coef = pd.DataFrame({'Feature': X_train.columns, 'Coefficient': lasso.coef_})
lasso_coef = lasso_coef[lasso_coef['Coefficient'] != 0]
lasso_coef = lasso_coef.sort_values(by='Coefficient', ascending=False)

print("Lasso Coefficients:")
print(lasso_coef)

lasso_coef.plot(kind='barh', x='Feature', y='Coefficient', title='Feature Coefficients in Lasso Model', figsize=(10, 12))
plt.xlabel('Coefficient Value')
plt.ylabel('Features')
plt.grid(True, linestyle='--')
plt.show()

threshold = 0.0001
selected_features = lasso_coef[lasso_coef['Coefficient'].abs() > threshold]['Feature'].tolist()
print("Selected features based on threshold:")
print(selected_features)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 824.6467050915307, tolerance: 638.6421683650191
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 793.5246465095697, tolerance: 638.6421683650191
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 768.4363996578577, tolerance: 638.6421683650191
#   model = cd_fast.enet_coordinate_descent_gram(
# ...

# %% [markdown]
# ****
#
# # **Player Stats**
#
# ****

# %% [markdown]
# ****
#
# ## **Player Hitting Stats (2023)**
#
# ****

# %%
player_hitting_stats = pd.DataFrame()

set = ['0', '25', '50', '75', '100', '125', '150']

for s in set:
    api_url = f'https://bdfed.stitch.mlbinfra.com/bdfed/stats/player?stitch_env=prod&season=2023&sportId=1&stats=season&group=hitting&gameType=R&limit=25&offset={s}&sortStat=onBasePlusSlugging&order=desc'
    r = requests.get(url=api_url).json()

    h_stats_df1 = pd.DataFrame(r['stats'])

    player_hitting_stats = pd.concat([player_hitting_stats, h_stats_df1], ignore_index=True)

# %%
player_hitting_stats
# Out:
#      year  playerId         playerName    type  rank     playerFullName  \
# 0    2023    660271      Shohei Ohtani  player     1      Shohei Ohtani
# 1    2023    608369       Corey Seager  player     2       Corey Seager
# 2    2023    660670   Ronald Acuña Jr.  player     3   Ronald Acuña Jr.
# 3    2023    621566         Matt Olson  player     4         Matt Olson
# 4    2023    605141       Mookie Betts  player     5       Mookie Betts
# ..    ...       ...                ...     ...   ...                ...
# 129  2023    656716     Zach McKinstry  player   130     Zach McKinstry
# 130  2023    571771  Enrique Hernández  player   131  Enrique Hernández
# 131  2023    664702        Myles Straw  player   132        Myles Straw
# 132  2023    595879        Javier Báez  player   133        Javier Báez
# 133  2023    641313       Tim Anderson  player   134       Tim Anderson
#
#     playerFirstName playerLastName playerUseName playerInitLastName  teamId  \
# ...

# %%
player_hitting_stats
# Out:
#      year  playerId         playerName    type  rank     playerFullName  \
# 0    2023    660271      Shohei Ohtani  player     1      Shohei Ohtani
# 1    2023    608369       Corey Seager  player     2       Corey Seager
# 2    2023    660670   Ronald Acuña Jr.  player     3   Ronald Acuña Jr.
# 3    2023    621566         Matt Olson  player     4         Matt Olson
# 4    2023    605141       Mookie Betts  player     5       Mookie Betts
# ..    ...       ...                ...     ...   ...                ...
# 129  2023    656716     Zach McKinstry  player   130     Zach McKinstry
# 130  2023    571771  Enrique Hernández  player   131  Enrique Hernández
# 131  2023    664702        Myles Straw  player   132        Myles Straw
# 132  2023    595879        Javier Báez  player   133        Javier Báez
# 133  2023    641313       Tim Anderson  player   134       Tim Anderson
#
#     playerFirstName playerLastName playerUseName playerInitLastName  teamId  \
# ...

# %% [markdown]
# ****
#
# ## **Player Pitching Stats (2023)**
#
# ****

# %%
player_pitching_stats = pd.DataFrame()

set = ['0', '25', '50', '75']

for s in set:
    api_url = f'https://bdfed.stitch.mlbinfra.com/bdfed/stats/player?stitch_env=prod&season=2024&sportId=1&stats=season&group=pitching&gameType=R&limit=25&offset={s}&sortStat=earnedRunAverage&order=asc'
    r = requests.get(url=api_url).json()

    h_stats_df1 = pd.DataFrame(r['stats'])

    player_pitching_stats = pd.concat([player_pitching_stats, h_stats_df1], ignore_index=True)

# %%
player_pitching_stats
# Out:
#     year  playerId       playerName    type  rank   playerFullName  \
# 0   2024    684007    Shota Imanaga  player     1    Shota Imanaga
# 1   2024    621244     José Berríos  player     2     José Berríos
# 2   2024    676710  Kutter Crawford  player     3  Kutter Crawford
# 3   2024    607625        Seth Lugo  player     4        Seth Lugo
# 4   2024    669302    Logan Gilbert  player     5    Logan Gilbert
# ..   ...       ...              ...     ...   ...              ...
# 74  2024    676979  Garrett Crochet  player    75  Garrett Crochet
# 75  2024    650644     Aaron Civale  player    76     Aaron Civale
# 76  2024    605397     Joe Musgrove  player    77     Joe Musgrove
# 77  2024    571578   Patrick Corbin  player    78   Patrick Corbin
# 78  2024    647336   Michael Soroka  player    79   Michael Soroka
#
#    playerFirstName playerLastName playerUseName playerInitLastName  teamId  \
# 0            Shota        Imanaga         Shota          S Imanaga     112
# ...

# %%
player_pitching_stats
# Out:
#     year  playerId       playerName    type  rank   playerFullName  \
# 0   2024    684007    Shota Imanaga  player     1    Shota Imanaga
# 1   2024    621244     José Berríos  player     2     José Berríos
# 2   2024    676710  Kutter Crawford  player     3  Kutter Crawford
# 3   2024    607625        Seth Lugo  player     4        Seth Lugo
# 4   2024    669302    Logan Gilbert  player     5    Logan Gilbert
# ..   ...       ...              ...     ...   ...              ...
# 74  2024    676979  Garrett Crochet  player    75  Garrett Crochet
# 75  2024    650644     Aaron Civale  player    76     Aaron Civale
# 76  2024    605397     Joe Musgrove  player    77     Joe Musgrove
# 77  2024    571578   Patrick Corbin  player    78   Patrick Corbin
# 78  2024    647336   Michael Soroka  player    79   Michael Soroka
#
#    playerFirstName playerLastName playerUseName playerInitLastName  teamId  \
# 0            Shota        Imanaga         Shota          S Imanaga     112
# ...

# %% [markdown]
# ****
#
# ## **Team Hitting & Pitching Stats (1990-2024)**
#
# ****

# %%
df_cols = player_hitting_stats.columns

# %%
hitting_stats = pd.DataFrame(columns=df_cols)
hitting_stats

begin_loop = time.time()

years = range(1990, 2025)
group = ['hitting', 'pitching']

for y in years:
    for g in group:
        api_url = f'https://bdfed.stitch.mlbinfra.com/bdfed/stats/team?stitch_env=prod&sportId=1&gameType=R&group={g}&order=desc&sortStat=homeRuns&stats=season&season={y}&limit=30&offset=0'
        r = requests.get(url=api_url, headers=headers).json()
        h_stats_df1 = pd.DataFrame(r['stats'])
        h_stats_df2 = pd.DataFrame({'Year':[y for i in range(len(h_stats_df1))],
                                    'group':[g for i in range(len(h_stats_df1))]})
        h_stats_df3 = pd.concat([h_stats_df2, h_stats_df1], axis=1)

        hitting_stats = pd.concat([hitting_stats, h_stats_df3], ignore_index=True)

        print(f'Finished scraping data for {y} season.')
        lag = np.random.uniform(1, 3)
        print (f'...waiting {round(lag,1)} seconds')
        time.sleep(lag)

hitting_stats = hitting_stats.sort_values(by=['Year', 'group', 'homeRuns', 'era'], ascending=[False, True, False, True])

print(f'Process completed in {time.time() - begin_loop} seconds')
# Out:
# Finished scraping data for 2002 season.
# ...waiting 1.8 seconds
# Finished scraping data for 2002 season.
# ...waiting 1.8 seconds
# Finished scraping data for 2003 season.
# ...waiting 2.5 seconds
# Finished scraping data for 2003 season.
# ...waiting 2.8 seconds
# Finished scraping data for 2004 season.
# ...waiting 2.5 seconds
# Finished scraping data for 2004 season.
# ...waiting 1.3 seconds
# Finished scraping data for 2005 season.
# ...waiting 2.4 seconds
# Finished scraping data for 2005 season.
# ...waiting 2.4 seconds
# Finished scraping data for 2006 season.
# ...waiting 1.9 seconds
# Finished scraping data for 2006 season.
# ...waiting 3.0 seconds
# Finished scraping data for 2007 season.
# ...waiting 1.1 seconds
# Finished scraping data for 2007 season.
# ...waiting 1.9 seconds
# Finished scraping data for 2008 season.
# ...waiting 1.3 seconds
# Finished scraping data for 2008 season.
# ...waiting 2.2 seconds
# Finished scraping data for 2009 season.
# ...

# %%
hitting_stats.fillna(0, inplace=True)

# %%
hitting_stats
# Out:
#       year  type rank      shortName teamId teamAbbrev              teamName  \
# 1260  2023  team    1        Atlanta    144        ATL        Atlanta Braves
# 1261  2023  team    2     LA Dodgers    119        LAD   Los Angeles Dodgers
# 1262  2023  team    3      Minnesota    142        MIN       Minnesota Twins
# 1263  2023  team    3          Texas    140        TEX         Texas Rangers
# 1264  2023  team    5      LA Angels    108        LAA    Los Angeles Angels
# ...    ...   ...  ...            ...    ...        ...                   ...
# 55    2002  team   26      Cleveland    114        CLE     Cleveland Indians
# 56    2002  team   27      St. Louis    138        STL   St. Louis Cardinals
# 57    2002  team   28        Oakland    133        OAK     Oakland Athletics
# 58    2002  team   29        Atlanta    144        ATL        Atlanta Braves
# 59    2002  team   30  San Francisco    137         SF  San Francisco Giants
#
# ...

# %%
hitting_stats.columns
# Out:
# Index(['year', 'type', 'rank', 'shortName', 'teamId', 'teamAbbrev', 'teamName',
#        'teamShortName', 'leagueAbbrev', 'leagueName', 'leagueShortName',
#        'gamesPlayed', 'groundOuts', 'airOuts', 'runs', 'doubles', 'triples',
#        'homeRuns', 'strikeOuts', 'baseOnBalls', 'intentionalWalks', 'hits',
#        'hitByPitch', 'avg', 'atBats', 'obp', 'slg', 'ops', 'caughtStealing',
#        'stolenBases', 'stolenBasePercentage', 'groundIntoDoublePlay',
#        'numberOfPitches', 'plateAppearances', 'totalBases', 'rbi',
#        'leftOnBase', 'sacBunts', 'sacFlies', 'babip', 'groundOutsToAirouts',
#        'catchersInterference', 'atBatsPerHomeRun', 'Year', 'group',
#        'gamesStarted', 'era', 'inningsPitched', 'wins', 'losses', 'saves',
#        'saveOpportunities', 'holds', 'blownSaves', 'earnedRuns', 'whip',
#        'battersFaced', 'outs', 'gamesPitched', 'completeGames', 'shutouts',
#        'strikes', 'strikePercentage', 'hitBatsmen', 'balks', 'wildPitches',
# ...
